# %%
from keras.preprocessing import image
from align_face import align, aligner
from utils import init_gpu, Faces, load_image
from PIL import Image, ExifTags

import numpy as np
import glob

# import detect_face
from skimage.transform import resize
sess = init_gpu(1)
# Out:
# GPU already initiated

# %%
# faces = Faces(["/Users/sixiongshan/Desktop/kash/kash1.jpg", "/Users/sixiongshan/Desktop/kash/kash2.jpg"], sess)
faces = Faces(glob.glob("/Users/sixiongshan/Desktop/images/*.*"), sess)
# Out:
# WARNING:tensorflow:From /Users/sixiongshan/venv/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Users/sixiongshan/Desktop/research/code/fawkes/fawkes/detect_face.py:216: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.

# %%
glob.glob("/Users/sixiongshan/Desktop/images/*.*")
# Out:
# ['/Users/sixiongshan/Desktop/images/heather.png',
#  '/Users/sixiongshan/Desktop/images/heather2.jpg',
#  '/Users/sixiongshan/Desktop/images/michelle1.jpg',
#  '/Users/sixiongshan/Desktop/images/michelle2.jpg',
#  '/Users/sixiongshan/Desktop/images/jenna2.jpg',
#  '/Users/sixiongshan/Desktop/images/emily1.png',
#  '/Users/sixiongshan/Desktop/images/jenna1.png',
#  '/Users/sixiongshan/Desktop/images/emily2.png']

# %%
# len(faces.cropped_index)
img = Image.open('/Users/sixiongshan/Desktop/images/jenna1.png').convert('RGB')

# %%
# img = image.img_to_array(img)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=99x145 at 0x16F789EF0>

# %%
img = Image.open('/Users/sixiongshan/Desktop/images/jenna1.png')

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=99x145 at 0x1710DA828>

# %%
f = faces.merge_faces(100 * np.ones((10, 224, 224, 3)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-8394eab2f077> in <module>
# ----> 1 f = faces.merge_faces(100 * np.ones((10, 224, 224, 3)))
#
# ~/Desktop/research/code/fawkes/fawkes/utils.py in merge_faces(self, cloaks)
#     104             callback_id = self.callback_idx[i]
#     105             bb = self.cropped_index[i]
# --> 106             self.cloaked_faces[callback_id][bb[1]:bb[3], bb[0]:bb[2], :] += reshape_cloak
#     107
#     108         return self.cloaked_faces
#
# ValueError: operands could not be broadcast together with shapes (664,603,4) (664,603,3) (664,603,4)

# %%
[i.shape for i in faces.org_faces]
# Out:
# [(505, 400, 3),
#  (220, 175, 3),
#  (1280, 720, 3),
#  (1280, 720, 3),
#  (3264, 2448, 3),
#  (742, 822, 4),
#  (145, 99, 4),
#  (694, 578, 4)]

# %%
image.array_to_img(f[1])

# %%
# img = load_image("/Users/sixiongshan/Desktop/kash/kash2.jpg")

# %%
# f = align(img, ali, margin=0.8)

# %%
# image.array_to_img(f[0][2])
